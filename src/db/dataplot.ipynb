# %%
import numpy as np
from pathlib import Path
import pandas as pd

# %%
Dir = Path("/dataset/LG/3_processed/0418_Hitomorrow_officetel/sr60/raw")
for file_path in Dir.glob("*.npz"):
    print(file_path)
    data = np.load(file_path, allow_pickle=True)
    print(data["timestamp"])
    
    start_time = pd.to_datetime(data["timestamp"][0], unit="s")
    end_time = pd.to_datetime(data["timestamp"][-1], unit="s")
    print(start_time, end_time)
    break
# Out:
# /dataset/LG/3_processed/0418_Hitomorrow_officetel/sr60/raw/idu_23_I0B.npz
# [1624976100 1624976160 1624976220 ... 1630454160 1630454220 1630454280]
# 2021-06-29 14:15:00 2021-08-31 23:58:00
