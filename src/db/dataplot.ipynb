# %%
import numpy as np
from pathlib import Path

# %%
Dir = Path("/dataset/LG/3_processed/0418_Hitomorrow_officetel/sr60/raw")
for file_path in Dir.glob("*.npz"):
    print(file_path)
    data = np.load(file, allow_pickle=True)
    print(data)
    break
# Out:
# [PosixPath('/dataset/LG/3_processed/0418_Hitomorrow_officetel/sr60/raw/idu_23_I0B.npz'), PosixPath('/dataset/LG/3_processed/0418_Hitomorrow_officetel/sr60/raw/idu_09_I31.npz'), PosixPath('/dataset/LG/3_processed/0418_Hitomorrow_officetel/sr60/raw/idu_08_IA0.npz'), PosixPath('/dataset/LG/3_processed/0418_Hitomorrow_officetel/sr60/raw/idu_04_I1C.npz'), PosixPath('/dataset/LG/3_processed/0418_Hitomorrow_officetel/sr60/raw/idu_07_I88.npz'), PosixPath('/dataset/LG/3_processed/0418_Hitomorrow_officetel/sr60/raw/idu_0D_I85.npz'), PosixPath('/dataset/LG/3_processed/0418_Hitomorrow_officetel/sr60/raw/idu_07_I9B.npz'), PosixPath('/dataset/LG/3_processed/0418_Hitomorrow_officetel/sr60/raw/idu_07_I8C.npz'), PosixPath('/dataset/LG/3_processed/0418_Hitomorrow_officetel/sr60/raw/idu_01_I09.npz'), PosixPath('/dataset/LG/3_processed/0418_Hitomorrow_officetel/sr60/raw/idu_0A_I74.npz'), PosixPath('/dataset/LG/3_processed/0418_Hitomorrow_officetel/sr60/raw/idu_18_I89.npz'), PosixPath('/dataset/LG/3_proc
# ...
